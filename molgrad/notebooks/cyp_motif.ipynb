# %%
import os
os.chdir('../..')
import numpy as np
import pickle
from tqdm import tqdm

# %%
from molgrad.vis import molecule_importance
from molgrad.utils import DATA_PATH, MODELS_PATH, EXAMPLE_PATH
from molgrad.train import DEVICE
from molgrad.prod import predict_mol
from rdkit.Chem.rdmolops import Kekulize

# %%
import torch
model_pt = os.path.join(MODELS_PATH, 'cyp_noHs.pt')

from molgrad.net import MPNNPredictor

model = MPNNPredictor(node_in_feats=49,
                      edge_in_feats=10,
                      global_feats=4,
                      n_tasks=1,
                      output_f=torch.sigmoid).to(DEVICE) 
model.load_state_dict(torch.load(model_pt,
                                 map_location=DEVICE))
# Out:
# <All keys matched successfully>

# %%
from rdkit.Chem import MolFromSmiles, MolToInchi
import pandas as pd

sar1 = pd.read_csv(os.path.join(DATA_PATH, 'cyp', 'cyp_sar1.csv'), sep=';')  ## nothing interesting
sar1
# Out:
#           substituent                                             SMILES  \
# 0         4-imidazole    COC1=CC2=C(C=C1OC)C=C(C=C2)C(O)(C(C)C)C1=CNC=N1
# 1          3-pyrazole    COC1=CC2=C(C=C1OC)C=C(C=C2)C(O)(C(C)C)C1=NNC=C1
# 2          4-pyrazole    COC1=CC2=C(C=C1OC)C=C(C=C2)C(O)(C(C)C)C1=CNN=C1
# 3  4-(1,2,3-Triazole)    COC1=CC2=C(C=C1OC)C=C(C=C2)C(O)(C(C)C)C1=CNN=N1
# 4  3-(1,2,4-Triazole)    COC1=CC2=C(C=C1OC)C=C(C=C2)C(O)(C(C)C)C1=NNC=N1
# 5          5-Thiazole    COC1=CC2=C(C=C1OC)C=C(C=C2)C(O)(C(C)C)C1=CN=CS1
# 6           5-Oxazole    COC1=CC2=C(C=C1OC)C=C(C=C2)C(O)(C(C)C)C1=CN=CO1
# 7          3-Pyridine  COC1=CC2=C(C=C1OC)C=C(C=C2)C(O)(C(C)C)C1=CN=CC=C1
# 8          4-Pyridine  COC1=CC2=C(C=C1OC)C=C(C=C2)C(O)(C(C)C)C1=CC=NC=C1
# 9        4-Pyrimidine  COC1=CC2=C(C=C1OC)C=C(C=C2)C(O)(C(C)C)C1=NC=NC=C1
#
#     value
# 0    1.60
# 1    1.80
# 2   27.00
# 3   57.00
# 4  100.00
# 5    0.77
# 6    6.50
# 7    9.40
# 8    4.50
# 9   18.00

# %%
mol = MolFromSmiles(sar1['SMILES'][0])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.1602], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar1['SMILES'][1])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.1316], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar1['SMILES'][2])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.0913], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar1['SMILES'][3])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.0529], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar1['SMILES'][4])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.0628], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar1['SMILES'][5])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.9456], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar1['SMILES'][6])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.1552], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar1['SMILES'][7])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.4156], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar1['SMILES'][8])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.2760], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar1['SMILES'][9])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.1031], device='cuda:0', grad_fn=<SelectBackward>)

# %%
sar2 = pd.read_csv(os.path.join(DATA_PATH, 'cyp', 'cyp_sar2.csv'))  # nothing too interesting
sar2
# Out:
#            name                                             SMILES  ic50(um)
# 0  ketoconazole  CC(=O)N1CCN(CC1)c2ccc(OC[C@H]3CO[C@@](Cn4ccnc4...      0.20
# 1     econazole            Clc1ccc(COC(Cn2ccnc2)c3ccc(Cl)cc3Cl)cc1      0.43
# 2    Miconazole        Clc1ccc(COC(Cn2ccnc2)c3ccc(Cl)cc3Cl)c(Cl)c1      0.85
# 3  Clotrimazole             Clc1ccccc1C(n2ccnc2)(c3ccccc3)c4ccccc4      0.05
# 4   fluconazole                 OC(Cn1cncn1)(Cn2cncn2)c3ccc(F)cc3F     25.00

# %%
mol = MolFromSmiles(sar2['SMILES'][0])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.9858], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar2['SMILES'][1])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                     version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.9815], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar2['SMILES'][2])
print(predict_mol(mol, model))

_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.9670], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar2['SMILES'][3])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.9957], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar2['SMILES'][4])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-3,
                                                      addHs=False)
img
# Out:
# tensor([0.7586], device='cuda:0', grad_fn=<SelectBackward>)

# %%
sar3 = pd.read_csv(os.path.join(DATA_PATH, 'cyp', 'cyp_sar3.csv'))  # can show 4-5
sar3
# Out:
#                  name                                             SMILES  \
# 0            pyridine                                        C1=CC=NC=C1
# 1  aminoethylpyridine                                     NCCC1=CN=CC=C1
# 2                   5                           NCCCCCC(=O)NCC1=CN=CC=C1
# 3                   4             CC(C)(C)OC(=O)NCCCCCC(=O)NCC1=CN=CC=C1
# 4                  11  CC(C)(C)OC(=O)N[C@H](CSCCC(=O)NCC1=CN=CC=C1)CC...
# 5                 15a  CC(C)(C)OC(=O)N[C@H](CSCCC(=O)NCC1=CN=CC=C1)CC...
# 6                 15b  CC(C)(C)OC(=O)N[C@H](CSCCC(=O)NCC1=CN=CC=C1)CC...
#
#    ic50(um)
# 0   4000.00
# 1   5000.00
# 2   1000.00
# 3     75.00
# 4     30.00
# 5      0.52
# 6      0.21

# %%
mol = MolFromSmiles(sar3['SMILES'][0])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([7.3932e-05], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar3['SMILES'][1])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.0008], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar3['SMILES'][2])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([3.0648e-06], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar3['SMILES'][3])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.0002], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar3['SMILES'][4])
print(predict_mol(mol, model))
svg_cyp_one_neg, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False,
                                                      img_height=275,
                                                      img_width=550)
img
# Out:
# tensor([0.2613], device='cuda:0', grad_fn=<SelectBackward>)

# %%
with open(os.path.join(EXAMPLE_PATH, "cyp_motif_one_neg.svg"), "w+") as handle:
    handle.write(svg_cyp_one_neg)

# %%
mol = MolFromSmiles(sar3['SMILES'][5])
print(predict_mol(mol, model))
svg_cyp_one_pos, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False,
                                                      img_height=275,
                                                      img_width=550)
img
# Out:
# tensor([0.9998], device='cuda:0', grad_fn=<SelectBackward>)

# %%
with open(os.path.join(EXAMPLE_PATH, "cyp_motif_one_pos.svg"), "w+") as handle:
    handle.write(svg_cyp_one_pos)

# %%
mol = MolFromSmiles(sar3['SMILES'][6])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.9974], device='cuda:0', grad_fn=<SelectBackward>)

# %%
sar4 = pd.read_csv(os.path.join(DATA_PATH, 'cyp', 'cyp_sar4.csv'))  # can show 0 -> 2
sar4
# Out:
#   name                                             SMILES   ic50(um)
# 0   1a   OCCN1CCN(CC1)C(=O)OC[C@H]1CCC[C@H](N1S(=O)(=O...       0.06
# 1   1b  OCCN1CCN(CC1)C(=O)OC1(CC1)[C@H]1CCC[C@H](N1S(=...       0.30
# 2    2  CC(C)(CO)N1CCN(CC1)C(=O)OC1(CC1)[C@H]1CCC[C@H]...       2.20

# %%
mol = MolFromSmiles(sar4[' SMILES'][0])
print(predict_mol(mol, model))
svg_cyp_two_pos, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False,
                                                      img_height=275,
                                                      img_width=550)
img
# Out:
# tensor([0.7309], device='cuda:0', grad_fn=<SelectBackward>)

# %%
with open(os.path.join(EXAMPLE_PATH, "cyp_motif_two_pos.svg"), "w+") as handle:
    handle.write(svg_cyp_two_pos)

# %%
mol = MolFromSmiles(sar4[' SMILES'][2])
print(predict_mol(mol, model))
svg_cyp_two_neg, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False,
                                                      img_height=275,
                                                      img_width=550)
img
# Out:
# tensor([0.3753], device='cuda:0', grad_fn=<SelectBackward>)

# %%
with open(os.path.join(EXAMPLE_PATH, "cyp_motif_two_neg.svg"), "w+") as handle:
    handle.write(svg_cyp_two_neg)

# %%
sar5 = pd.read_csv(os.path.join(DATA_PATH, 'cyp', 'cyp_sar5.csv'))  # 16 weird behaviour
sar5
# Out:
#     Compound_number                                             SMILES  \
# 0                 1  CN1C(=N)N[C@]2(CN(C[C@H]2C1=O)C1=NC=C(F)C=N1)C...
# 1                 2  N=C(N[C@@]1(C2=CC(C3=CC(C#N)=C(F)C=C3)=CS2)CN4...
# 2                 3  N=C(N[C@@]1(C2=CC(C3=CC(C#N)=C(Cl)C=C3)=CS2)CN...
# 3                 4  N=C1N(C([C@H]2[C@](C3=CC(C4=CC(C#N)=CC(F)=C4)=...
# 4                 5  N=C1N(C([C@H]2[C@](C3=CC(C4=CC(C#N)=CC(OC)=C4)...
# 5                 6  N=C(N[C@@]1(C2=CC(C3=CC(F)=CC(F)=C3)=CS2)CN4C5...
# 6                 7  N=C(N[C@@]1(C2=CC(C3=CC(Cl)=CC=C3)=CS2)CN4C5=N...
# 7                 8  N=C1N(C([C@H]2[C@](C3=CC(Br)=CS3)(CN(C4=NC=C(F...
# 8                 9  CN1C(=N)N[C@]2(CN(C[C@H]2C1=O)C1=NC=C(F)C=C1)C...
# 9                10  CN1C(=N)N[C@]2(CN(C[C@H]2C1=O)C1=CC=C(F)C=C1)C...
# 10               11  CN1C(=N)N[C@]2(CN(C[C@H]2C1=O)C1=NC=CC=N1)C1=C...
# 11               12  N#CC1=CC=CC(C2=CSC([C@]3(CN4C(N=C5C)=NC=C5F)[C...
# 12               13  N#CC1=CC=CC(C2=CSC([C@@]([C@@H](C3)C4=O)(CN3C(...
# 13               14  N#CC1=CC=CC(C2=CSC([C@@]([C@@H](C3)C4=O)(CN3C5...
# 14               15  N#CC1=CC=CC(C2=CSC([C@@]([C@@H](C3)C(N4C)=O)(C...
# 15               16  N#CC1=CC=CC(C2=CSC([C@@]([C@@H](C3)C4=O)(CN3C5...
# 16               17  N#CC1=CC=CC(C2=CSC([C@]34CN(C(N=C5N6CCCC6)=NC=...
# 17               18  N#CC1=CC=CC(C2=CSC([C@@]([C@@H](C3)C(N4C)=O)(C...
# 18               19  N#CC1=CC=CC(C2=CSC([C@]3(CN4C(N=C5C)=NC(C)=C5F...
# 19               20  CC1=NC(N2C[C@@H](C(N(C(N3)=N)C)=O)[C@]3(C4=CC(...
#
#     CYP(um)
# 0       1.2
# 1       5.7
# 2       5.5
# 3       1.6
# 4       1.6
# 5       1.0
# 6       1.2
# 7       0.9
# 8       6.4
# 9      30.0
# 10     30.0
# 11      0.6
# 12      0.9
# 13      1.3
# 14      0.7
# 15      1.2
# 16     30.0
# 17     30.0
# 18     13.0
# 19     11.0

# %%
mol = MolFromSmiles(sar5['SMILES'][0])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.9816], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar5['SMILES'][1])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.6450], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar5['SMILES'][2])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.6859], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar5['SMILES'][3])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.9981], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar5['SMILES'][4])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.9963], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar5['SMILES'][5])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.6955], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar5['SMILES'][6])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.7286], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar5['SMILES'][7])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.5603], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar5['SMILES'][8])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.9875], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar5['SMILES'][9])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.9905], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar5['SMILES'][10])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.9727], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar5['SMILES'][11])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.0632], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar5['SMILES'][12])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.9915], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar5['SMILES'][13])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.9992], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar5['SMILES'][14])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.8659], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar5['SMILES'][14])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.8659], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar5['SMILES'][15])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.9991], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar5['SMILES'][16])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.0101], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar5['SMILES'][17])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.9691], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar5['SMILES'][18])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.0600], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar5['SMILES'][19])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.4459], device='cuda:0', grad_fn=<SelectBackward>)

# %%
sar6 = pd.read_csv(os.path.join(DATA_PATH, 'cyp', 'cyp_sar6.csv'))  # 12 -> 15
sar6
# Out:
#     name                                             SMILES  value(um)
# 0     14  CC(C)(CO)N1CCN(CC1)C(=O)OC1(CC1)[C@H]1COC[C@@H...        2.5
# 1     19  CS(C)(N1[C@@H](COC[C@@H]1C1(CC1)OC(=O)N1CC2CCC...        2.2
# 2     20  CN1C2CCC1CN(C2)C(=O)OC1(CC1)[C@H]1COC[C@@H](C2...        3.2
# 3     21  CCN1C2CCC1CN(C2)C(=O)OC1(CC1)[C@H]1COC[C@@H](C...        3.4
# 4     22  CS(C)(N1[C@@H](COC[C@@H]1C1(CC1)OC(=O)N1CC2CCC...       20.0
# 5     23  CC(=O)N1C2CCC1CN(C2)C(=O)OC1(CC1)[C@H]1COC[C@@...       30.0
# 6     24  CN(C)CC(=O)N1C2CCC1CN(C2)C(=O)OC1(CC1)[C@H]1CO...       30.0
# 7     25  CS(C)(N1[C@@H](COC[C@@H]1C1(CC1)OC(=O)N1CC2CCC...       16.0
# 8     26  CS(C)(N1[C@@H](COC[C@@H]1C1(CC1)OC(=O)N1C2CCC1...        0.3
# 9     27  CN1CC2CCC(C1)N2C(=O)OC1(CC1)[C@H]1COC[C@@H](C2...        0.5
# 10    28  CS(C)(N1[C@@H](COC[C@@H]1C1(CC1)OC(=O)N1C2CCC1...        1.0
# 11    29  CS(C)(N1[C@@H](COC[C@@H]1C1(CC1)OC(=O)N1CCC(CC...       30.0
# 12    30  CC(C)(COO)C1CCN(CC1)C(=O)OC1(CC1)[C@H]1COC[C@@...       30.0
# 13    31  CS(C)(N1[C@@H](COC[C@@H]1C1(CC1)OC(=O)N1CCC(CC...       15.0
# 14    32  CS(C)(N1[C@@H](COC[C@@H]1C1(CC1)OC(=O)N1CC[C@@...       30.0
# 15    33  CS(C)(N1[C@@H](COC[C@@H]1C1(CC1)OC(=O)N1CC[C@@...       11.0

# %%
mol = MolFromSmiles(sar6['SMILES'][0])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.1640], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar6['SMILES'][1])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.7953], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar6['SMILES'][2])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.8144], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar6['SMILES'][3])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.3076], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar6['SMILES'][4])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.7973], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar6['SMILES'][5])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.8154], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar6['SMILES'][6])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.7976], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar6['SMILES'][7])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.8108], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar6['SMILES'][8])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.7862], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar6['SMILES'][9])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.7808], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar6['SMILES'][10])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.7854], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar6['SMILES'][11])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.8033], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar6['SMILES'][12])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.3691], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar6['SMILES'][13])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.8226], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar6['SMILES'][14])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.8207], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar6['SMILES'][15])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.7914], device='cuda:0', grad_fn=<SelectBackward>)

# %%
sar7 = pd.read_csv(os.path.join(DATA_PATH, 'cyp', 'cyp_sar7.csv'))  
sar7
# Out:
#    name                                             SMILES  value(um)
# 0    34  C[C@@H]1OC[C@@H](N([C@@H]1C1CC1)S(=O)(=O)C1=CC...        0.3
# 1    35  C[C@@H]1OC[C@@H](N([C@@H]1C1CC1)S(=O)(=O)C1=CC...        4.8
# 2    36  C[C@H]1OC[C@@H](N([C@@H]1C1CC1)S(=O)(=O)C1=CC=...        0.5
# 3    37  C[C@H]1OC[C@@H](N([C@@H]1C1CC1)S(=O)(=O)C1=CC=...       24.0
# 4    38  CC1(C)OC[C@@H](N([C@@H]1C1CC1)S(=O)(=O)C1=CC=C...        0.3
# 5    39  CC(=O)N1C2CCC1N(C2)C(=O)OC1(CC1)[C@H]1COC(C)(C...        6.7

# %%
mol = MolFromSmiles(sar7['SMILES'][0])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.8829], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar7['SMILES'][1])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.9453], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar7['SMILES'][2])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.8759], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar7['SMILES'][3])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.9409], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar7['SMILES'][4])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.8869], device='cuda:0', grad_fn=<SelectBackward>)

# %%
mol = MolFromSmiles(sar7['SMILES'][5])
print(predict_mol(mol, model))
_, img, _, _, global_importance = molecule_importance(mol,
                                                      model,
                                                      task=0,
                                                      version=2,
                                                      vis_factor=1,
                                                      eps=1e-4,
                                                      addHs=False)
img
# Out:
# tensor([0.8186], device='cuda:0', grad_fn=<SelectBackward>)
