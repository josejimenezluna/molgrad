# %%
import os
os.chdir('../..')

import numpy as np
import pandas as pd
import torch
import pickle
from tqdm import tqdm
from molexplain.utils import DATA_PATH

# %%
with open(os.path.join(DATA_PATH, 'ppb', 'data_ppb.pt'), 'rb') as handle:
    inchis, values = pickle.load(handle)

# %%
with open(os.path.join(DATA_PATH, 'ppb', 'atom_importances.pt'), 'rb') as handle:
    atom_importances = pickle.load(handle)

# %%
len(atom_importances)
# Out:
# 4634

# %%
len(inchis)
# Out:
# 4634

# %%
atom_importances[0]
# Out:
# array([ 0.12807932, -0.76260614,  0.75035936,  0.60856694,  1.5749204 ,
#         0.05659312,  0.05659312, -0.03471758,  0.11427534,  0.2764058 ],
#       dtype=float32)

# %%
avg_imp = [np.mean(ai) for ai in atom_importances]
sum_imp = [np.sum(ai) for ai in atom_importances]
max_imp = [np.max(ai) for ai in atom_importances]

# %%
import matplotlib.pyplot as plt
plt.hist(avg_imp)
plt.show()

# %%
plt.hist(sum_imp)
plt.show()

# %%
plt.scatter(values, avg_imp)

# %%
np.corrcoef(values, avg_imp)
# Out:
# array([[1.       , 0.2212962],
#        [0.2212962, 1.       ]])

# %%
plt.scatter(values, sum_imp)

# %%
np.corrcoef(values, sum_imp)
# Out:
# array([[1.        , 0.27935695],
#        [0.27935695, 1.        ]])

# %%
plt.scatter(values, max_imp)

# %%
np.corrcoef(values, max_imp)
# Out:
# array([[1.        , 0.12951456],
#        [0.12951456, 1.        ]])

# %%
plt.scatter(values, np.abs(sum_imp))

# %%
np.corrcoef(values, np.abs(sum_imp))
# Out:
# array([[1.        , 0.19625455],
#        [0.19625455, 1.        ]])
